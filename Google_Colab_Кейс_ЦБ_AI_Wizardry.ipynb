# %% [markdown]
# # Импортируем библиотеки

# %%
# !pip install pymorphy2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.5 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1 (from pymorphy2)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2)
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 36.5 MB/s eta 0:00:00
# Collecting docopt>=0.6 (from pymorphy2)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=92e8db5d4693b6bd44cad089a739c940bebaeb28d067016a5b3c4a0a864f7f0a
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
import pandas as pd                # Импорт библиотеки pandas для работы с данными в формате DataFrame
import numpy as np                 # Импорт библиотеки numpy для работы с массивами и вычислений
import re                          # Импорт модуля re для работы с регулярными выражениями
import pymorphy2                   # Импорт библиотеки pymorphy2 для морфологического анализа слов
import nltk                        # Импорт библиотеки nltk для обработки текста
import matplotlib.pyplot as plt    # Импорт библиотеки matplotlib.pyplot для построения графиков
from nltk.corpus import stopwords  # Импорт списка стоп-слов из библиотеки nltk
from sklearn.feature_extraction.text import TfidfVectorizer  # Импорт класса TfidfVectorizer для векторизации текста
from sklearn.preprocessing import StandardScaler           # Импорт класса StandardScaler для стандартизации данных
from sklearn.model_selection import train_test_split       # Импорт функции train_test_split для разделения данных на обучающую и тестовую выборки
from sklearn.svm import SVC         # Импорт класса SVC для реализации метода опорных векторов
from sklearn.preprocessing import OneHotEncoder  # Импорт класса OneHotEncoder для кодирования категориальных признаков
from sklearn.impute import SimpleImputer  # Импорт класса SimpleImputer из модуля sklearn.impute
from sklearn.metrics import f1_score      # Импорт функции f1_score из модуля sklearn.metrics
from sklearn.ensemble import IsolationForest
from typing import Literal

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Первичный анализ данных**

# %%
df = pd.read_csv('/content/drive/MyDrive/hacaton/train.csv')

# %%
date_columns = ['Дата восстановления', 'Дата обращения', "Дата закрытия обращения", "Крайний срок"]
df[date_columns] = df[date_columns].apply(pd.to_datetime)

# %%
print(f"Количество записей: {df.shape[0]}")  # Подсчет количества записей в датафрейме

service_counts = df['Сервис'].value_counts() # Подсчет количества уникальных значений в столбце "Категория"
print("Количество записей по сервисам:")
print(service_counts)

functional_group_counts = df['Функциональная группа'].value_counts()             # подсчет количества уникальных значений в столбце "Функциональная группа"
print("Количество записей по функциональной группе:")
print(functional_group_counts)

df['Время обработки'] = df['Дата закрытия обращения'] - df['Дата обращения']     # Вычисление среднего значения в столбце "Время обработки"
mean_processing_time = df['Время обработки'].mean()
print(f"Среднее время обработки: {mean_processing_time} дней")

priority_counts = df.groupby('Приоритет').size()                                 # Группировка записей по столбцу "Приоритет" и подсчет количества записей в каждой группе
print("Количество записей по приоритету:")
print(priority_counts)
# Out:
# Количество записей: 14803
# Количество записей по сервисам:
# АРМ          3434
# Сервис7      1746
# Сервис22     1567
# Сервис13      838
# Сервис2       808
#              ...
# Сервис208       1
# Сервис390       1
# Сервис201       1
# Сервис336       1
# Сервис193       1
# Name: Сервис, Length: 153, dtype: int64
# Количество записей по функциональной группе:
# ФГ13     3320
# ФГ12     1122
# ФГ8      1103
# ФГ18      787
# ФГ137     407
#          ...
# ФГ743       1
# ФГ485       1
# ФГ535       1
# ФГ600       1
# ФГ234       1
# Name: Функциональная группа, Length: 555, dtype: int64
# Среднее время обработки: 7 days 11:23:36.272008872 дней
# Количество записей по приоритету:
# Приоритет
# 0-Критический        3
# 1-Высокий           12
# 2-Средний         4694
# 3-Низкий         10094
# dtype: int64

# %% [markdown]
# # **ПОДГОТОВКА ДАННЫХ**

# %% [markdown]
# ### Создание функций для очистки данных

# %%
def process_date(df_firstprocess):
    """
    Обрабатывает дату в DataFrame и Удаляет строки, у которых в столбце "Содержание" есть пропущенные значения.
    Параметры:
    - df_with_date_title (pandas.DataFrame): DataFrame с данными, содержащими столбцы с датой и столбец "Содержание".

    Возвращает:
    обработанный датафрейм
    Пример использования:
    >>> process_date(df)
    """

    df = df_firstprocess
    df.dropna(subset=['Содержание'], inplace=True)  # Удаление строк, у которых в столбце 'Содержание' есть пропущенные значения.

    date_columns = ['Дата восстановления', 'Дата обращения', "Дата закрытия обращения", "Крайний срок"]
    df[date_columns] = df[date_columns].apply(pd.to_datetime)  # Преобразование столбцов с датами в формат datetime

    mean_diff = (df['Дата восстановления'] - df['Дата обращения']).mean()  # Расчёт средней разницы между столбцами 'Дата восстановления' и 'Дата обращения'
    df['Дата восстановления'].fillna(df['Дата обращения'] + mean_diff, inplace=True)  # заполнение пропущенных значений в 'Дата восстановления' средним значением
    df['Дата восстановления'] = df['Дата восстановления'].dt.date  # преобразование столбца 'Дата восстановления' в формат date

    mean_diff2 = (df['Дата закрытия обращения'] - df['Дата обращения']).mean()  # Расчет средней разницы между столбцами 'Дата закрытия обращения' и 'Дата обращения'
    df['Дата закрытия обращения'].fillna(df['Дата обращения'] + mean_diff2, inplace=True)  # заполнение пропущенных значений в 'Дата закрытия обращения' средним значением
    df['Дата закрытия обращения'] = df['Дата закрытия обращения'].dt.date
    return df

# %%
def process_digit(df_processes, typedf: Literal['train', 'test']):
    """
    Обрабатывает столбцы в DataFrame и переводит строчные значения в численные.
    Параметры:
    - df_processes (pandas.DataFrame): DataFrame с данными, содержащими столбцы 'Сервис','Приоритет','Функциональная группа',
    'Критичность','Влияние','Система','Место', 'Тип обращения на момент подачи' и если Датафрейм тренировочный 'Тип обращения итоговый'.
    - typedf(str): строка, обозначающая тип выборки входного Датафрейма
    Возвращает:
    обработанный датафрейм
    Примеры использования:
    >>> process_digit(df, 'train')
    >>> process_digit(df, 'test')
    """
    df = df_processes
    df['Приоритет'] = df['Приоритет'].str[0].astype(
        int)  # Извлекает первый символ из столбца 'Приоритет', преобразует его в целое число и присваивает обратно в столбец 'Приоритет'
    df['Критичность'] = df['Критичность'].str[0].astype(
        int)  # Извлекает первый символ из столбца 'Критичность', преобразует его в целое число и присваивает обратно в столбец 'Критичность'
    df['Влияние'] = df['Влияние'].str[0].astype(
        int)  # Извлекает первый символ из столбца 'Влияние', преобразует его в целое число и присваивает обратно в столбец 'Влияние'
    df['Место'] = df['Место'].str.replace('[^\d.]+', '', regex=True).replace({"": 0}).astype(
        int)  # Удаляет все символы, кроме цифр и точки, из столбца 'Место', заменяет пустые строки на 0 и преобразует значения в целые числа
    df['Сервис'] = df['Сервис'].str.replace('[^\d.]+', '', regex=True).replace({"": 0}).astype(
        int)  # Удаляет все символы, кроме цифр и точки, из столбца 'Сервис', заменяет пустые строки на 0 и преобразует значения в целые числа
    df['Статус'] = df['Статус'].map({"Закрыт": 0,
                                     'Отменен': 1})  # Заменяет значения в столбце 'Статус' с помощью словаря: 'Закрыт' на 0, 'Отменен' на 1
    df['Система'] = df['Система'].str.replace('[^\d.]+', '', regex=True).replace({"": 0}).astype(
        int)  # Удаляет все символы, кроме цифр и точки, из столбца 'Система', заменяет пустые строки на 0 и преобразует значения в целые числа
    df['Функциональная группа'] = df['Функциональная группа'].str.replace('[^\d.]+', '', regex=True).astype(
        int)  # Удаляет все символы, кроме цифр и точки, из столбца 'Функциональная группа' и преобразует значения в целые числа
    if typedf == 'train':
        df['Тип обращения итоговый'] = df['Тип обращения итоговый'].replace({"Запрос": 0,
                                                                            'Инцидент': 1})  # Заменяет значения в столбце 'Тип обращения итоговый' с помощью словаря: 'Запрос' на 0, 'Инцидент' на 1
    df['Тип обращения на момент подачи'] = df['Тип обращения на момент подачи'].replace({"Запрос": 0,
                                                                                         'Инцидент': 1})  # Заменяет значения в столбце 'Тип обращения на момент подачи' с помощью словаря: 'Запрос' на 0, 'Инцидент' на 1
    return df

# %%
def scaler(df):
  scaler = StandardScaler()  # Создание экземпляра объекта StandardScaler для стандартизации данных.
  columns_to_standardize = ['Сервис', 'Приоритет', 'Функциональная группа', 'Критичность', 'Влияние', 'Система', 'Место']
  df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize]).round(3)  # Стандартизирует выбранные столбцы данных с помощью метода fit_transform() объекта StandardScaler 
  #  Значения в столбцах будут заменены на их стандартизованные значения, округленные до 3 десятичных знаков.
  return df

# %% [markdown]
# ## **train.csv**

# %%
df = process_date(df)  # Преобразуем строковые значения дат в формат date

# %%
df = process_digit(df, 'train')  # преобразуем строчные данные в столбцах в численные

# %%
scaler(df)  # Стандартизация данных
# Out:
#                                               Содержание  Сервис  Приоритет  \
# 0                                                   Тест  -0.669      0.681
# 1                                     Тестовое обращение  -0.669      0.681
# 2               Выполнена разблокировка у/з REGION\*****  -0.484     -1.450
# 3                                      .Не включается ПК  -0.669      0.681
# 4              Заявка № ***********, *******************  -0.669      0.681
# ...                                                  ...     ...        ...
# 14798   разблокировка учетной записи пользователя вСе...  -0.484     -1.450
# 14799  Устранение уязвимостей ИБ в соответствии с Пла...  -0.669      0.681
# 14800            Контроль ПУ. Заявка на доступ к портам.  -0.616      0.681
# 14801                                    Ремонт стульев.   1.253      0.681
# 14802  Заявка на предоставление и отзыв прав доступа ...  -0.090      0.681
#
#        Статус  Функциональная группа        Крайний срок      Дата обращения  \
# 0           1                 -0.713 2018-01-24 07:42:00 2018-01-19 09:27:00
# 1           1                 -0.713 2018-01-24 10:51:00 2018-01-19 09:36:00
# 2           0                 -0.672 2018-01-31 07:51:00 2018-01-25 22:47:00
# 3           0                  1.569 2018-01-28 05:50:00 2018-01-25 23:13:00
# 4           0                  1.058 2018-02-03 02:51:00 2018-01-25 23:39:00
# ...       ...                    ...                 ...                 ...
# 14798       0                 -0.672 2018-02-21 14:17:00 2018-02-16 13:02:00
# 14799       0                  0.073 2018-02-21 14:36:00 2018-02-16 13:07:00
# 14800       0                  1.129 2018-02-21 14:23:00 2018-02-16 13:08:00
# 14801       0                  0.214 2018-02-21 14:24:00 2018-02-16 13:09:00
# 14802       0                 -0.643 2018-02-18 13:10:00 2018-02-16 13:10:00
#
#        Тип обращения на момент подачи  Тип обращения итоговый  \
# 0                                   0                       0
# 1                                   0                       0
# 2                                   0                       0
# 3                                   1                       1
# 4                                   0                       0
# ...                               ...                     ...
# 14798                               0                       0
# 14799                               0                       0
# 14800                               0                       0
# 14801                               0                       0
# 14802                               0                       0
#
#                                     Решение               \
# 0                                                   Тест
# 1                                                   Тест
# 2      Выполнена разблокировка у/з Ne_bosS\*********\...
# 3                             Выход из стоя БП. Заменён.
# 4                          Работы по обращению выполнены
# ...                                                  ...
# 14798   Личность пользователя идентифицирована\nПричи...
# 14799                                          Выполнено
# 14800                  Работы выполнены согласно заявке.
# 14801                                          выполнено
# 14802                      Работы по обращению выполнены
#
#        Тип переклассификации Дата восстановления Дата закрытия обращения  \
# 0                          0          2018-01-21              2018-01-19
# 1                          0          2018-01-21              2018-01-19
# 2                          0          2018-01-25              2018-02-02
# 3                          0          2018-01-25              2018-01-26
# 4                          0          2018-01-28              2018-02-04
# ...                      ...                 ...                     ...
# 14798                      0          2018-02-16              2018-02-23
# 14799                      0          2018-02-21              2018-03-07
# 14800                      0          2018-02-21              2018-03-07
# 14801                      0          2018-02-17              2018-02-24
# 14802                      0          2018-02-17              2018-02-23
#
#        Критичность  Влияние  Система  Место
# 0            1.005   -1.229   -0.648 -1.030
# 1            1.005   -1.229   -0.648 -1.030
# 2           -1.245   -1.229   -0.514  1.477
# 3            1.005   -1.229   -0.648  1.305
# 4            1.005    0.780   -0.648  1.820
# ...            ...      ...      ...    ...
# 14798       -1.245   -1.229   -0.514 -0.371
# 14799        1.005   -1.229   -0.648 -0.991
# 14800        1.005    0.780   -0.610  1.120
# 14801        1.005    0.780    0.715 -0.991
# 14802       -0.495    0.780    1.292 -0.674
#
# [14802 rows x 17 columns]

# %% [markdown]
# ## **test.csv**

# %%
df_test = pd.read_csv("/content/drive/MyDrive/hacaton/test.csv")

# %%
df_test = process_date(df_test)  # Преобразуем строковые значения дат в формат date

# %%
df_test = process_digit(df_test, 'test')  # преобразуем строчные данные в столбцах в численные

# %%
scaler(df_test)  # Стандартизация данных
# Out:
#          id                                         Содержание  Сервис  \
# 0     14803  Заявка на предоставление и отзыв прав доступа ...   0.383
# 1     14804                                  Транспортный шлюз   0.931
# 2     14805  Заявка на предоставление и отзыв прав доступа ...  -0.137
# 3     14806  Заявка на предоставление и отзыв прав доступа ...   1.752
# 4     14807  Заявка на предоставление и отзыв прав доступа ...  -0.137
# ...     ...                                                ...     ...
# 6339  21142  <Бот-наблюдения> Система53. Ухудшение статуса ...   0.712
# 6340  21143  <Бот-наблюдения> Система52. Ухудшение статуса ...   0.684
# 6341  21144  <Бот-наблюдения> Система11. Ухудшение статуса ...  -0.438
# 6342  21145  <Бот-наблюдения>Система364. Ухудшение статуса ...  -0.630
# 6343  21146                      Деактуализация запросов банка  -0.602
#
#       Приоритет  Статус  Функциональная группа        Крайний срок  \
# 0         0.631       0                 -0.572 2018-02-22 07:51:00
# 1        -1.576       0                 -0.656 2018-02-21 14:36:00
# 2         0.631       0                 -0.572 2018-03-31 06:36:00
# 3         0.631       1                 -0.572 2018-02-21 14:29:00
# 4         0.631       0                 -0.572 2018-03-30 09:36:00
# ...         ...     ...                    ...                 ...
# 6339      0.631       0                 -0.635 2018-03-07 14:36:00
# 6340     -1.576       0                 -0.635 2018-03-07 14:06:00
# 6341      0.631       0                 -0.635 2018-03-09 12:36:00
# 6342      0.631       0                 -0.628 2018-03-09 12:36:00
# 6343      0.631       0                 -0.621 2018-03-10 06:36:00
#
#           Дата обращения  Тип обращения на момент подачи  \
# 0    2018-02-16 13:11:00                               0
# 1    2018-02-16 13:13:00                               0
# 2    2018-02-16 13:13:00                               0
# 3    2018-02-16 13:14:00                               0
# 4    2018-02-16 13:14:00                               0
# ...                  ...                             ...
# 6339 2018-02-25 20:56:00                               1
# 6340 2018-02-25 20:58:00                               1
# 6341 2018-02-25 21:05:00                               1
# 6342 2018-02-25 21:16:00                               1
# 6343 2018-02-25 21:35:00                               0
#
#       Тип обращения итоговый  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 6339                     NaN
# 6340                     NaN
# 6341                     NaN
# 6342                     NaN
# 6343                     NaN
#
#                                    Решение               \
# 0                         Работы по обращению выполнены
# 1                                           проинф у.о.
# 2                         Работы по обращению выполнены
# 3     Запрос отменён пользователем из портала самооб...
# 4                         Работы по обращению выполнены
# ...                                                 ...
# 6339                                 самовосстановление
# 6340                                 самовосстановление
# 6341                                 самовосстановление
# 6342                                 Самовосстановление
# 6343                          Деактуализация проведена.
#
#       Тип переклассификации Дата восстановления Дата закрытия обращения  \
# 0                       NaN          2018-02-18              2018-02-25
# 1                       NaN          2018-02-16              2018-02-24
# 2                       NaN          2018-03-15              2018-03-23
# 3                       NaN          2018-02-16              2018-02-28
# 4                       NaN          2018-03-15              2018-03-23
# ...                     ...                 ...                     ...
# 6339                    NaN          2018-02-26              2018-03-14
# 6340                    NaN          2018-02-26              2018-03-14
# 6341                    NaN          2018-02-26              2018-03-14
# 6342                    NaN          2018-03-07              2018-03-14
# 6343                    NaN          2018-03-07              2018-03-15
#
#       Критичность  Влияние  Система  Место
# 0           1.104    0.748    0.190 -0.516
# 1          -1.254   -1.277    0.574 -1.034
# 2          -0.468    0.748   -0.449 -0.693
# 3          -0.468    0.748    7.010 -1.020
# 4          -0.468    0.748   -0.449 -0.693
# ...           ...      ...      ...    ...
# 6339       -0.468   -1.277    0.403 -1.020
# 6340       -1.254   -1.277    0.382 -1.020
# 6341        1.104   -1.277   -0.492 -1.020
# 6342       -0.468   -1.277   -0.641 -1.020
# 6343       -0.468   -1.277   -0.620 -1.007
#
# [6344 rows x 18 columns]

# %% [markdown]
# ## **Лемматизация и векторизация признаков train.csv + test.csv**
#
# **Для столбца содержание**

# %%
nltk.download('stopwords')  # Загрузка списка стоп-слов из библиотеки NLTK
stop_words = set(stopwords.words('russian'))  # Создание множества стоп-слов на русском языке
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['Содержание'] = df['Содержание'].apply(lambda x: re.sub('[^а-яА-Я]', ' ', str(x)))         # Удаление символов, отличных от русских букв
df['Содержание'] = df['Содержание'].apply(lambda x: x.lower())                                # Приведение к нижнему регистру

df_test['Содержание'] = df_test['Содержание'].apply(lambda x: re.sub('[^а-яА-Я]', ' ', str(x)))  # Удаление символов, отличных от русских букв
df_test['Содержание'] = df_test['Содержание'].apply(lambda x: x.lower())                      # Приведение к нижнему регистру

morph_sod_test = pymorphy2.MorphAnalyzer()  # Создание экземпляра морфологического анализатора для обработки содержания в тестовом наборе данных
df_test['Содержание'] = df_test['Содержание'].apply(lambda x: ' '.join([morph_sod_test.parse(word)[0].normal_form for word in x.split() if word not in stop_words]))  # Применение морфологического анализа и удаление стоп-слов в тестовом наборе данных

vectorizer_sod_test = TfidfVectorizer()     # Создание экземпляра векторизатора TF-IDF для содержания в тестовом наборе данных
X_sod_test = vectorizer_sod_test.fit_transform(df_test['Содержание'])                         # Применение векторизатора TF-IDF к содержанию в тестовом наборе данных

feature_names_sod_test = vectorizer_sod_test.get_feature_names_out()                          # Получение списка имен признаков из векторизатора TF-IDF в тестовом наборе данных
df_features_sod_test = pd.DataFrame(X_sod_test.toarray(), columns=feature_names_sod_test)     # Создание датафрейма признаков на основе векторов TF-IDF в тестовом наборе данных

morph_sod = pymorphy2.MorphAnalyzer()  # Создание экземпляра морфологического анализатора для обработки содержания
df['Содержание'] = df['Содержание'].apply(lambda x: ' '.join([morph_sod.parse(word)[0].normal_form for word in x.split() if word not in stop_words]))  # Применение морфологического анализа и удаление стоп-слов

vectorizer_sod = TfidfVectorizer()                  # Создание экземпляра векторизатора TF-IDF для содержания
X = vectorizer_sod.fit_transform(df['Содержание'])  # Применение векторизатора TF-IDF к содержанию

feature_names = vectorizer_sod.get_feature_names_out()          # Получение списка имен признаков из векторизатора TF-IDF
df_features = pd.DataFrame(X.toarray(), columns=feature_names)  # Создание датафрейма признаков на основе векторов TF-IDF

df_features_sod = pd.concat([df_features_sod_test, df_features], axis=1)  # Объединение датафреймов признаков из тестового и обучающего наборов данных

# %% [markdown]
# **Для столбца Решение**

# %%
df.iloc[:, 9] = df.iloc[:, 9].apply(lambda x: re.sub('[^а-яА-Я]', ' ', str(x)))  # Удаление символов, отличных от русских букв
df.iloc[:, 9] = df.iloc[:, 9].apply(lambda x: x.lower())                         # Приведение к нижнему регистру

df_test.iloc[:, 10] = df_test.iloc[:, 10].apply(lambda x: re.sub('[^а-яА-Я]', ' ', str(x)))  # Удаление символов, отличных от русских букв
df_test.iloc[:, 10] = df_test.iloc[:, 10].apply(lambda x: x.lower())                         # Приведение к нижнему регистру

morph_res_test = pymorphy2.MorphAnalyzer()  # Создание экземпляра морфологического анализатора для обработки результата в тестовом наборе данных
df_test.iloc[:, 10] = df_test.iloc[:, 10].apply(lambda x: ' '.join([morph_res_test.parse(word)[0].normal_form for word in x.split() if word not in stop_words]))  # Применение морфологического анализа и удаление стоп-слов в тестовом наборе данных для результата

vectorizer_res_test = TfidfVectorizer()                               # Создание экземпляра векторизатора TF-IDF для результата в тестовом наборе данных
X_res_test = vectorizer_res_test.fit_transform(df_test.iloc[:, 10])   # Применение векторизатора TF-IDF к результату в тестовом наборе данных

feature_names_res_test = vectorizer_res_test.get_feature_names_out()  # Получение списка имен признаков из векторизатора TF-IDF в тестовом наборе данных для результата
df_features_res_test = pd.DataFrame(X_res_test.toarray(), columns=feature_names_res_test)  # Создание датафрейма признаков на основе векторов TF-IDF в тестовом наборе данных для результата

morph = pymorphy2.MorphAnalyzer()                                     # Создание экземпляра морфологического анализатора для обработки результата
df.iloc[:, 9] = df.iloc[:, 9].apply(lambda x: ' '.join([morph.parse(word)[0].normal_form for word in x.split() if word not in stop_words]))  # Применение морфологического анализа и удаление стоп-слов для результата

vectorizer = TfidfVectorizer()                                        # Создание экземпляра векторизатора TF-IDF для результата
X_res = vectorizer.fit_transform(df.iloc[:, 9])                       # Применение векторизатора TF-IDF к результату

feature_names_res = vectorizer.get_feature_names_out()                # Получение списка имен признаков из векторизатора TF-IDF для результата
df_features_res = pd.DataFrame(X_res.toarray(), columns=feature_names_res)    # Создание датафрейма признаков на основе векторов TF-IDF для результата

df_features_res = pd.concat([df_features_res_test, df_features_res], axis=1)  # Объединение датафреймов признаков для результата

# %%
df.head()
# Out:
#                   Содержание  Сервис  Приоритет  Статус  \
# 0                       тест  -0.669      0.681       1
# 1         тестовый обращение  -0.669      0.681       1
# 2  выполнить разблокировка з  -0.484     -1.450       0
# 3              включаться пк  -0.669      0.681       0
# 4                     заявка  -0.669      0.681       0
#
#    Функциональная группа        Крайний срок      Дата обращения  \
# 0                 -0.713 2018-01-24 07:42:00 2018-01-19 09:27:00
# 1                 -0.713 2018-01-24 10:51:00 2018-01-19 09:36:00
# 2                 -0.672 2018-01-31 07:51:00 2018-01-25 22:47:00
# 3                  1.569 2018-01-28 05:50:00 2018-01-25 23:13:00
# 4                  1.058 2018-02-03 02:51:00 2018-01-25 23:39:00
#
#    Тип обращения на момент подачи  Тип обращения итоговый  \
# 0                               0                       0
# 1                               0                       0
# 2                               0                       0
# 3                               1                       1
# 4                               0                       0
#
#                                 Решение               Тип переклассификации  \
# 0                                               тест                      0
# 1                                               тест                      0
# 2  выполнить разблокировка з идентификация пользо...                      0
# 3                             выход стоя бп замена н                      0
# 4                         работа обращение выполнить                      0
#
#   Дата восстановления Дата закрытия обращения  Критичность  Влияние  Система  \
# 0          2018-01-21              2018-01-19        1.005   -1.229   -0.648
# 1          2018-01-21              2018-01-19        1.005   -1.229   -0.648
# 2          2018-01-25              2018-02-02       -1.245   -1.229   -0.514
# 3          2018-01-25              2018-01-26        1.005   -1.229   -0.648
# 4          2018-01-28              2018-02-04        1.005    0.780   -0.648
#
#    Место
# 0 -1.030
# 1 -1.030
# 2  1.477
# 3  1.305
# 4  1.820

# %%
df_test.head()
# Out:
#       id                                       Содержание  Сервис  Приоритет  \
# 0  14803  заявка предоставление отзыв право доступ ресурс   0.383      0.631
# 1  14804                                транспортный шлюз   0.931     -1.576
# 2  14805  заявка предоставление отзыв право доступ ресурс  -0.137      0.631
# 3  14806  заявка предоставление отзыв право доступ ресурс   1.752      0.631
# 4  14807  заявка предоставление отзыв право доступ ресурс  -0.137      0.631
#
#    Статус  Функциональная группа        Крайний срок      Дата обращения  \
# 0       0                 -0.572 2018-02-22 07:51:00 2018-02-16 13:11:00
# 1       0                 -0.656 2018-02-21 14:36:00 2018-02-16 13:13:00
# 2       0                 -0.572 2018-03-31 06:36:00 2018-02-16 13:13:00
# 3       1                 -0.572 2018-02-21 14:29:00 2018-02-16 13:14:00
# 4       0                 -0.572 2018-03-30 09:36:00 2018-02-16 13:14:00
#
#    Тип обращения на момент подачи  Тип обращения итоговый  \
# 0                               0                     NaN
# 1                               0                     NaN
# 2                               0                     NaN
# 3                               0                     NaN
# 4                               0                     NaN
#
#                                 Решение               Тип переклассификации  \
# 0                         работа обращение выполнить                    NaN
# 1                                             проинф                    NaN
# 2                         работа обращение выполнить                    NaN
# 3  запрос отмена н пользователь портал самообслуж...                    NaN
# 4                         работа обращение выполнить                    NaN
#
#   Дата восстановления Дата закрытия обращения  Критичность  Влияние  Система  \
# 0          2018-02-18              2018-02-25        1.104    0.748    0.190
# 1          2018-02-16              2018-02-24       -1.254   -1.277    0.574
# 2          2018-03-15              2018-03-23       -0.468    0.748   -0.449
# 3          2018-02-16              2018-02-28       -0.468    0.748    7.010
# 4          2018-03-15              2018-03-23       -0.468    0.748   -0.449
#
#    Место
# 0 -0.516
# 1 -1.034
# 2 -0.693
# 3 -1.020
# 4 -0.693

# %% [markdown]
# ## **0 Обучение модели с признаками Содержание и Решение**

# %%
selected_features = ['Сервис', 'Приоритет', 'Статус', 'Функциональная группа', 'Тип обращения на момент подачи', 'Критичность', 'Влияние', 'Система', 'Место']
df_selected_features = df[selected_features].reset_index(drop=True)                     # Выбор и сброс индексов выбранных признаков в датафрейме df

df_train = pd.concat([df_selected_features, df_features_sod, df_features_res], axis=1)  # Объединение датафреймов df_selected_features, df_features_sod и df_features_res по столбцам

# %%
X_train = df_train.values                     # Преобразование датафрейма df_train в массив значений для признаков (обучающая выборка)
y_train = df['Тип переклассификации'].values  # Присвоение массиву значений целевой переменной 'Тип переклассификации' из датафрейма df

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)  # Разделение обучающей выборки на обучающий и тестовый наборы

# %%
print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (11841, 4328)
# (11841,)
# (2961, 4328)
# (2961,)

# %%
imputer = SimpleImputer(strategy='mean')         # Создание объекта SimpleImputer

X_train_filled = imputer.fit_transform(X_train)  # Применение imputer к X_train

model = SVC()                                    # Обучение модели на заполненных данных
model.fit(X_train_filled, y_train)
# Out:
# SVC()

# %%
X_test_filled = imputer.transform(X_test)  # Применение imputer к X_test

y_pred = model.predict(X_test_filled)      # Предсказание на заполненных данных

accuracy = (y_pred == y_test).mean()       # Вычисление точности
print(f"Точность: {accuracy}")
# Out:
# Точность: 0.9861533265788585

# %%
f1_macro = f1_score(y_test, y_pred, average='macro')  # Вычисление макро-усредненной F1-меры
print("Macro-average F1-score:", f1_macro)            # Вывод значения макро-усредненной F1-меры
# Out:
# Macro-average F1-score: 0.7505950988592799

# %% [markdown]
# ## **1 Обучение модели без признаков Содержание и Решение**

# %%
X_train = df[['Сервис', 'Приоритет', 'Статус', 'Функциональная группа', 'Тип обращения на момент подачи', 'Критичность',	'Влияние',	'Система',	'Место']]

# %%
y_train = df['Тип переклассификации']

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

model = SVC()
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

accuracy = (y_pred == y_test).mean()
print(f"Точность: {accuracy}")
# Out:
# Точность: 0.9810874704491725

# %%
f1_macro = f1_score(y_test, y_pred, average='macro')  # Вычисление макро-усредненной F1-меры
print("Macro-average F1-score:", f1_macro)            # Вывод значения макро-усредненной F1-меры
# Out:
# Macro-average F1-score: 0.5832828254199424

# %%
X_train = df[['Сервис', 'Приоритет', 'Статус', 'Функциональная группа', 'Тип обращения на момент подачи', 'Критичность',	'Влияние',	'Система',	'Место']]
y_train = df['Тип обращения итоговый']

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

model2 = SVC()
model2.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model2.predict(X_test)

accuracy = (y_pred == y_test).mean()
print(f"Точность: {accuracy}")
# Out:
# Точность: 0.9787234042553191

# %%
f1_macro = f1_score(y_test, y_pred, average='macro')  # Вычисление макро-усредненной F1-меры
print("Macro-average F1-score:", f1_macro)            # Вывод значения макро-усредненной F1-меры
# Out:
# Macro-average F1-score: 0.7831341688977966

# %% [markdown]
# ## **Тестовый датасет test.csv**

# %%
df_test.head()
# Out:
#       id                                       Содержание  Сервис  Приоритет  \
# 0  14803  заявка предоставление отзыв право доступ ресурс   0.383      0.631
# 1  14804                                транспортный шлюз   0.931     -1.576
# 2  14805  заявка предоставление отзыв право доступ ресурс  -0.137      0.631
# 3  14806  заявка предоставление отзыв право доступ ресурс   1.752      0.631
# 4  14807  заявка предоставление отзыв право доступ ресурс  -0.137      0.631
#
#    Статус  Функциональная группа        Крайний срок      Дата обращения  \
# 0       0                 -0.572 2018-02-22 07:51:00 2018-02-16 13:11:00
# 1       0                 -0.656 2018-02-21 14:36:00 2018-02-16 13:13:00
# 2       0                 -0.572 2018-03-31 06:36:00 2018-02-16 13:13:00
# 3       1                 -0.572 2018-02-21 14:29:00 2018-02-16 13:14:00
# 4       0                 -0.572 2018-03-30 09:36:00 2018-02-16 13:14:00
#
#    Тип обращения на момент подачи  Тип обращения итоговый  \
# 0                               0                     NaN
# 1                               0                     NaN
# 2                               0                     NaN
# 3                               0                     NaN
# 4                               0                     NaN
#
#                                 Решение               Тип переклассификации  \
# 0                         работа обращение выполнить                    NaN
# 1                                             проинф                    NaN
# 2                         работа обращение выполнить                    NaN
# 3  запрос отмена н пользователь портал самообслуж...                    NaN
# 4                         работа обращение выполнить                    NaN
#
#   Дата восстановления Дата закрытия обращения  Критичность  Влияние  Система  \
# 0          2018-02-18              2018-02-25        1.104    0.748    0.190
# 1          2018-02-16              2018-02-24       -1.254   -1.277    0.574
# 2          2018-03-15              2018-03-23       -0.468    0.748   -0.449
# 3          2018-02-16              2018-02-28       -0.468    0.748    7.010
# 4          2018-03-15              2018-03-23       -0.468    0.748   -0.449
#
#    Место
# 0 -0.516
# 1 -1.034
# 2 -0.693
# 3 -1.020
# 4 -0.693

# %%
X_test = df_test[['Сервис', 'Приоритет', 'Статус', 'Функциональная группа', 'Тип обращения на момент подачи', 'Критичность',	'Влияние',	'Система',	'Место']]

# %%
y_pred_pereclass = model.predict(X_test)           # предсказания Тип переклассификации

# %%
y_pred_itog = model2.predict(X_test)               # предсказания Тип обращения итоговый

# %%
print(len(y_pred_pereclass[y_pred_pereclass!=0]))  # количество ненулевых данных
# Out:
# 279

# %%
print(len(y_pred_itog[y_pred_itog!=0]))            # количество ненулевых данных
# Out:
# 124

# %% [markdown]
# ## Количество переклассификаций в тестовом датасете test.csv

# %%
count_nonzero = np.count_nonzero(y_pred)

print(f"Количество переклассификаций: {count_nonzero}")
# Out:
# Количество переклассификаций: 55

# %% [markdown]
# ## **Вывод результатов в файл**

# %%
submission_df = pd.read_csv('/content/drive/MyDrive/hacaton/submission.csv')  # Загрузка существующего файла submission.csv

# %%
submission_df['Тип переклассификации'] = y_pred_pereclass                            # Заполнение столбцов "Тип переклассификаций"
submission_df['Тип обращения итоговый'] = y_pred_itog                                # Заполнение столбцов "Тип обращения итоговый"

submission_df.to_csv('/content/drive/MyDrive/hacaton/submission.csv', index=False)   # Сохранение обновленного DataFrame в файл CSV

# %% [markdown]
# # **Выявление аномалий. Анализ данных**

# %%
df = pd.read_csv('/content/drive/MyDrive/hacaton/train.csv')

df = process_date(df)  # Преобразуем строковые значения дат в формат date
df = process_digit(df, 'train')  # Преобразуем строчные данные в столбцах в численные

# %%
df1 = df[['Сервис', 'Приоритет', 'Статус', 'Функциональная группа', 'Тип обращения на момент подачи', 'Критичность',	'Влияние',	'Система',	'Место']]

# Создаем и обучаем модель Isolation Forest
clf = IsolationForest(contamination=0.1)  # contamination - ожидаемая доля аномалий в данных
clf.fit(df1)

# Предсказываем аномалии
y_pred = clf.predict(df1)

# Выводим результаты
res = []
res_tuple = []
for i, row in enumerate(df1.iterrows()):
    if y_pred[i] == -1:
        print(f"Пример {i+1} является аномалией. При том что: 'Сервис'={df1.iloc[i, 0]}, 'Приоритет'={['Критический', 'Высокий   ', 'Средний   ', 'Низкий    '][df1.iloc[i, 1]]}, 'Статус'={['Закрыт    ', 'Отменен   '][df1.iloc[i, 2]]}, 'Функциональная группа'={df1.iloc[i, 3]}, 'Тип обращения на момент подачи'={['Запрос    ', 'Инцидент  '][df1.iloc[i, 4]]}, 'Критичность'={['Особая    ', 'Повышенная', 'Базовая   ', 'Нет       '][df1.iloc[i, 5]-1]},	'Влияние'={['Всеохватывающее', 'Значительное', 'Малое     ', 'Нет влияния'][df1.iloc[i, 6]-1]},	'Система'={df1.iloc[i, 7]},	'Место'={df1.iloc[i, 8]}")
        res.append(i+1)
        res_tuple.append((df1.iloc[i, 0], df1.iloc[i, 1], df1.iloc[i, 2], df1.iloc[i, 3], df1.iloc[i, 4], df1.iloc[i, 5], df1.iloc[i, 6], df1.iloc[i, 7], df1.iloc[i, 8]))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# Пример 4 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=390, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=0,	'Место'=177
# Пример 11 является аномалией. При том что: 'Сервис'=58, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=303, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=58,	'Место'=216
# Пример 13 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=360, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=197
# Пример 15 является аномалией. При том что: 'Сервис'=347, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=136, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Значительное,	'Система'=304,	'Место'=1
# Пример 20 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=20
# Пример 25 является аномалией. При том что: 'Сервис'=205, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=217, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=218,	'Место'=143
# Пример 30 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=825, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=143
# Пример 35 является аномалией. При том что: 'Сервис'=154, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=628, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=97,	'Место'=143
# Пример 37 является аномалией. При том что: 'Сервис'=154, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=628, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=97,	'Место'=143
# Пример 50 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=430, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=0,	'Место'=106
# Пример 72 является аномалией. При том что: 'Сервис'=287, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=211, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=0
# Пример 89 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=334, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=159
# Пример 105 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=177
# Пример 115 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=334, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=216
# Пример 116 является аномалией. При том что: 'Сервис'=92, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=593, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=33,	'Место'=92
# Пример 122 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=528, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=7,	'Место'=257
# Пример 139 является аномалией. При том что: 'Сервис'=142, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=343, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=153,	'Место'=172
# Пример 152 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=87, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=157
# Пример 164 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=825, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=143
# Пример 227 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=89, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=0,	'Место'=59
# Пример 254 является аномалией. При том что: 'Сервис'=26, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=728, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=26,	'Место'=52
# Пример 270 является аномалией. При том что: 'Сервис'=121, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=19, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=125,	'Место'=0
# Пример 290 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=742, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=7,	'Место'=198
# Пример 295 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=742, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=7,	'Место'=198
# Пример 296 является аномалией. При том что: 'Сервис'=121, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=19, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=125,	'Место'=116
# Пример 315 является аномалией. При том что: 'Сервис'=22, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=137, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=22,	'Место'=48
# Пример 319 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=129, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=0,	'Место'=7
# Пример 328 является аномалией. При том что: 'Сервис'=77, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=785, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=76,	'Место'=82
# Пример 362 является аномалией. При том что: 'Сервис'=26, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=720, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=26,	'Место'=89
# Пример 363 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=122, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=181
# Пример 367 является аномалией. При том что: 'Сервис'=99, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=84, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Значительное,	'Система'=100,	'Место'=122
# Пример 376 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=253, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=0,	'Место'=116
# Пример 392 является аномалией. При том что: 'Сервис'=58, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=372, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=58,	'Место'=216
# Пример 393 является аномалией. При том что: 'Сервис'=205, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=303, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=218,	'Место'=216
# Пример 396 является аномалией. При том что: 'Сервис'=154, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=303, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=97,	'Место'=216
# Пример 397 является аномалией. При том что: 'Сервис'=205, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=372, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=218,	'Место'=216
# Пример 405 является аномалией. При том что: 'Сервис'=320, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=56, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=368,	'Место'=1
# Пример 409 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=39
# Пример 433 является аномалией. При том что: 'Сервис'=93, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=592, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=92,	'Место'=69
# Пример 434 является аномалией. При том что: 'Сервис'=66, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=30, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=65,	'Место'=116
# Пример 437 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=39
# Пример 471 является аномалией. При том что: 'Сервис'=77, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=76,	'Место'=164
# Пример 483 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Малое     ,	'Система'=18,	'Место'=100
# Пример 485 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=395, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=146
# Пример 500 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=395, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=146
# Пример 547 является аномалией. При том что: 'Сервис'=115, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=341,	'Место'=139
# Пример 554 является аномалией. При том что: 'Сервис'=87, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=188, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=87,	'Место'=3
# Пример 556 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=19, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=20,	'Место'=34
# Пример 557 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=515, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=0,	'Место'=150
# Пример 574 является аномалией. При том что: 'Сервис'=44, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=145,	'Место'=224
# Пример 575 является аномалией. При том что: 'Сервис'=44, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=145,	'Место'=224
# Пример 576 является аномалией. При том что: 'Сервис'=44, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=145,	'Место'=224
# Пример 577 является аномалией. При том что: 'Сервис'=138, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=240, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Малое     ,	'Система'=130,	'Место'=16
# Пример 590 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=62, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=174
# Пример 607 является аномалией. При том что: 'Сервис'=73, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=114, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=71,	'Место'=2
# Пример 673 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=35,	'Место'=13
# Пример 681 является аномалией. При том что: 'Сервис'=26, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=464, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=26,	'Место'=200
# Пример 696 является аномалией. При том что: 'Сервис'=161, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=653, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=169,	'Место'=16
# Пример 741 является аномалией. При том что: 'Сервис'=26, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=616, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=26,	'Место'=169
# Пример 747 является аномалией. При том что: 'Сервис'=132, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=117, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Значительное,	'Система'=91,	'Место'=2
# Пример 749 является аномалией. При том что: 'Сервис'=136, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=603, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=148,	'Место'=1
# Пример 750 является аномалией. При том что: 'Сервис'=136, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=603, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=148,	'Место'=1
# Пример 751 является аномалией. При том что: 'Сервис'=136, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=603, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=148,	'Место'=1
# Пример 753 является аномалией. При том что: 'Сервис'=136, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=603, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=148,	'Место'=1
# Пример 754 является аномалией. При том что: 'Сервис'=136, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=603, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=148,	'Место'=1
# Пример 778 является аномалией. При том что: 'Сервис'=84, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=489,	'Место'=90
# Пример 808 является аномалией. При том что: 'Сервис'=125, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=482,	'Место'=13
# Пример 823 является аномалией. При том что: 'Сервис'=185, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=479, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=200,	'Место'=52
# Пример 860 является аномалией. При том что: 'Сервис'=223, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=243,	'Место'=3
# Пример 864 является аномалией. При том что: 'Сервис'=223, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=243,	'Место'=3
# Пример 865 является аномалией. При том что: 'Сервис'=223, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=243,	'Место'=3
# Пример 867 является аномалией. При том что: 'Сервис'=223, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=243,	'Место'=3
# Пример 868 является аномалией. При том что: 'Сервис'=223, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=243,	'Место'=3
# Пример 884 является аномалией. При том что: 'Сервис'=58, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=634, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=58,	'Место'=1
# Пример 892 является аномалией. При том что: 'Сервис'=64, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=669, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=64,	'Место'=213
# Пример 897 является аномалией. При том что: 'Сервис'=73, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=567, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=71,	'Место'=218
# Пример 906 является аномалией. При том что: 'Сервис'=2, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=619, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=161
# Пример 909 является аномалией. При том что: 'Сервис'=22, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=668, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=22,	'Место'=198
# Пример 916 является аномалией. При том что: 'Сервис'=181, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=25, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=194,	'Место'=21
# Пример 917 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=172
# Пример 918 является аномалией. При том что: 'Сервис'=58, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=716, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=58,	'Место'=1
# Пример 922 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=172
# Пример 923 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=172
# Пример 924 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=172
# Пример 930 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=41, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=185
# Пример 931 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=159
# Пример 933 является аномалией. При том что: 'Сервис'=287, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=211, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=0
# Пример 951 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=149
# Пример 961 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=75, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=56
# Пример 969 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=89
# Пример 971 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=75, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=32
# Пример 973 является аномалией. При том что: 'Сервис'=2, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=169, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=173
# Пример 975 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=75, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=56
# Пример 986 является аномалией. При том что: 'Сервис'=2, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=2,	'Место'=174
# Пример 988 является аномалией. При том что: 'Сервис'=99, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=85, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=100,	'Место'=173
# Пример 997 является аномалией. При том что: 'Сервис'=142, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=318, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=153,	'Место'=172
# Пример 1000 является аномалией. При том что: 'Сервис'=401, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=163, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=470,	'Место'=43
# Пример 1043 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=48, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=35,	'Место'=57
# Пример 1046 является аномалией. При том что: 'Сервис'=13, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=38, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=13,	'Место'=51
# Пример 1060 является аномалией. При том что: 'Сервис'=13, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=121, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=13,	'Место'=82
# Пример 1061 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=75, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=32
# Пример 1063 является аномалией. При том что: 'Сервис'=2, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=99, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=220
# Пример 1092 является аномалией. При том что: 'Сервис'=2, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=409, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=0
# Пример 1097 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=14, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=134,	'Место'=57
# Пример 1101 является аномалией. При том что: 'Сервис'=115, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=341,	'Место'=9
# Пример 1108 является аномалией. При том что: 'Сервис'=132, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=117, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Значительное,	'Система'=91,	'Место'=2
# Пример 1111 является аномалией. При том что: 'Сервис'=207, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=536, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=222,	'Место'=0
# Пример 1113 является аномалией. При том что: 'Сервис'=41, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=43,	'Место'=13
# Пример 1121 является аномалией. При том что: 'Сервис'=207, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=536, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=222,	'Место'=0
# Пример 1127 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=295, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=0,	'Место'=16
# Пример 1131 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=200
# Пример 1132 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=75, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=56
# Пример 1163 является аномалией. При том что: 'Сервис'=294, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=59, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=333,	'Место'=1
# Пример 1168 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=35,	'Место'=13
# Пример 1185 является аномалией. При том что: 'Сервис'=66, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=53, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=65,	'Место'=140
# Пример 1195 является аномалией. При том что: 'Сервис'=2, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=800, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=150
# Пример 1216 является аномалией. При том что: 'Сервис'=13, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=13,	'Место'=177
# Пример 1285 является аномалией. При том что: 'Сервис'=205, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=346, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=321,	'Место'=66
# Пример 1306 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=183
# Пример 1309 является аномалией. При том что: 'Сервис'=22, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=448, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=22,	'Место'=73
# Пример 1322 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=110
# Пример 1339 является аномалией. При том что: 'Сервис'=13, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=24, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=105,	'Место'=294
# Пример 1360 является аномалией. При том что: 'Сервис'=154, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=56, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=97,	'Место'=3
# Пример 1414 является аномалией. При том что: 'Сервис'=181, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=25, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=194,	'Место'=1
# Пример 1423 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=385, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=246,	'Место'=164
# Пример 1424 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=385, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=246,	'Место'=164
# Пример 1433 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=94, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=13,	'Место'=173
# Пример 1443 является аномалией. При том что: 'Сервис'=54, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=4, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=54,	'Место'=1
# Пример 1444 является аномалией. При том что: 'Сервис'=171, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=128, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=180,	'Место'=54
# Пример 1447 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=598, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=52,	'Место'=3
# Пример 1453 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=0,	'Место'=400
# Пример 1455 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=0,	'Место'=400
# Пример 1468 является аномалией. При том что: 'Сервис'=92, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=354, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=99,	'Место'=200
# Пример 1473 является аномалией. При том что: 'Сервис'=41, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=62, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=43,	'Место'=61
# Пример 1479 является аномалией. При том что: 'Сервис'=73, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=480, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=71,	'Место'=102
# Пример 1481 является аномалией. При том что: 'Сервис'=92, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=354, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=99,	'Место'=200
# Пример 1502 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=192, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=257,	'Место'=141
# Пример 1505 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=30, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=0,	'Место'=53
# Пример 1528 является аномалией. При том что: 'Сервис'=171, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=128, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=180,	'Место'=95
# Пример 1555 является аномалией. При том что: 'Сервис'=93, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=399, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=92,	'Место'=69
# Пример 1561 является аномалией. При том что: 'Сервис'=11, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=11,	'Место'=137
# Пример 1563 является аномалией. При том что: 'Сервис'=132, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=117, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Значительное,	'Система'=91,	'Место'=2
# Пример 1566 является аномалией. При том что: 'Сервис'=11, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=11,	'Место'=137
# Пример 1575 является аномалией. При том что: 'Сервис'=48, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=85, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=48,	'Место'=15
# Пример 1577 является аномалией. При том что: 'Сервис'=65, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=45, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=105,	'Место'=13
# Пример 1589 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=35,	'Место'=156
# Пример 1594 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=154, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=33,	'Место'=3
# Пример 1596 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=245, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=50
# Пример 1599 является аномалией. При том что: 'Сервис'=95, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=629, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=94,	'Место'=41
# Пример 1603 является аномалией. При том что: 'Сервис'=52, 'Приоритет'=Высокий   , 'Статус'=Отменен   , 'Функциональная группа'=6, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Значительное,	'Система'=52,	'Место'=1
# Пример 1613 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=57
# Пример 1627 является аномалией. При том что: 'Сервис'=133, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=5, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=146,	'Место'=65
# Пример 1641 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=27,	'Место'=116
# Пример 1646 является аномалией. При том что: 'Сервис'=161, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=169,	'Место'=2
# Пример 1648 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=33
# Пример 1684 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=122, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=77
# Пример 1711 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=54
# Пример 1745 является аномалией. При том что: 'Сервис'=138, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=241, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Малое     ,	'Система'=130,	'Место'=31
# Пример 1747 является аномалией. При том что: 'Сервис'=138, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=241, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Малое     ,	'Система'=130,	'Место'=31
# Пример 1749 является аномалией. При том что: 'Сервис'=138, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=241, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Малое     ,	'Система'=130,	'Место'=31
# Пример 1879 является аномалией. При том что: 'Сервис'=138, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=240, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Малое     ,	'Система'=130,	'Место'=5
# Пример 1905 является аномалией. При том что: 'Сервис'=142, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=318, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=153,	'Место'=172
# Пример 1931 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=19, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=20,	'Место'=240
# Пример 1941 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=177
# Пример 1948 является аномалией. При том что: 'Сервис'=99, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=84, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=100,	'Место'=240
# Пример 1961 является аномалией. При том что: 'Сервис'=22, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=137, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=22,	'Место'=57
# Пример 1965 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=190
# Пример 1966 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=122, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=91
# Пример 1968 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=565, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=35,	'Место'=58
# Пример 1976 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=8, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=7,	'Место'=173
# Пример 1986 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=620, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=91
# Пример 1995 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=19, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=20,	'Место'=16
# Пример 2008 является аномалией. При том что: 'Сервис'=25, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=271, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=25,	'Место'=24
# Пример 2009 является аномалией. При том что: 'Сервис'=25, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=390, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=25,	'Место'=302
# Пример 2011 является аномалией. При том что: 'Сервис'=25, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=271, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=25,	'Место'=24
# Пример 2017 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=343, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=0,	'Место'=172
# Пример 2031 является аномалией. При том что: 'Сервис'=22, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=7, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=22,	'Место'=10
# Пример 2040 является аномалией. При том что: 'Сервис'=65, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=7, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Значительное,	'Система'=105,	'Место'=31
# Пример 2041 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=129, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=35,	'Место'=3
# Пример 2079 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=679, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=200,	'Место'=139
# Пример 2081 является аномалией. При том что: 'Сервис'=415, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=496, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=483,	'Место'=30
# Пример 2089 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=169
# Пример 2093 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=92
# Пример 2101 является аномалией. При том что: 'Сервис'=12, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=58, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=244,	'Место'=51
# Пример 2115 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=23, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=22
# Пример 2132 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=334, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=159
# Пример 2133 является аномалией. При том что: 'Сервис'=185, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=579, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=200,	'Место'=159
# Пример 2137 является аномалией. При том что: 'Сервис'=90, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=377, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=73,	'Место'=157
# Пример 2138 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=334, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=216
# Пример 2152 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=334, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=216
# Пример 2153 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=334, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=216
# ...
# Пример 14100 является аномалией. При том что: 'Сервис'=132, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=4, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=91,	'Место'=1
# Пример 14101 является аномалией. При том что: 'Сервис'=132, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=4, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=91,	'Место'=1
# Пример 14102 является аномалией. При том что: 'Сервис'=132, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=4, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=91,	'Место'=1
# Пример 14103 является аномалией. При том что: 'Сервис'=132, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=4, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=91,	'Место'=1
# Пример 14104 является аномалией. При том что: 'Сервис'=132, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=4, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=91,	'Место'=1
# Пример 14105 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=328, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=246,	'Место'=197
# Пример 14107 является аномалией. При том что: 'Сервис'=287, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=211, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=0
# Пример 14115 является аномалией. При том что: 'Сервис'=1, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=211, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=1,	'Место'=0
# Пример 14128 является аномалией. При том что: 'Сервис'=56, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=192, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=56,	'Место'=1
# Пример 14156 является аномалией. При том что: 'Сервис'=13, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=62, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=59,	'Место'=141
# Пример 14171 является аномалией. При том что: 'Сервис'=121, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=549, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=125,	'Место'=173
# Пример 14191 является аномалией. При том что: 'Сервис'=73, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=294, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=71,	'Место'=106
# Пример 14196 является аномалией. При том что: 'Сервис'=121, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=549, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=125,	'Место'=15
# Пример 14201 является аномалией. При том что: 'Сервис'=84, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=312,	'Место'=235
# Пример 14202 является аномалией. При том что: 'Сервис'=84, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=312,	'Место'=235
# Пример 14246 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=154, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=33,	'Место'=41
# Пример 14253 является аномалией. При том что: 'Сервис'=22, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=101,	'Место'=178
# Пример 14276 является аномалией. При том что: 'Сервис'=21, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=421, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=21,	'Место'=308
# Пример 14277 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=19, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Значительное,	'Система'=20,	'Место'=1
# Пример 14278 является аномалией. При том что: 'Сервис'=77, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=58, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=141,	'Место'=370
# Пример 14295 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=177
# Пример 14350 является аномалией. При том что: 'Сервис'=206, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=549, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=221,	'Место'=15
# Пример 14356 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=154, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=33,	'Место'=76
# Пример 14370 является аномалией. При том что: 'Сервис'=155, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=238, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=161,	'Место'=1
# Пример 14381 является аномалией. При том что: 'Сервис'=66, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=30, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=65,	'Место'=116
# Пример 14388 является аномалией. При том что: 'Сервис'=26, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=720, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=26,	'Место'=89
# Пример 14398 является аномалией. При том что: 'Сервис'=142, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=318, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=153,	'Место'=172
# Пример 14409 является аномалией. При том что: 'Сервис'=107, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=4, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Значительное,	'Система'=54,	'Место'=1
# Пример 14418 является аномалией. При том что: 'Сервис'=133, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=140, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=146,	'Место'=24
# Пример 14432 является аномалией. При том что: 'Сервис'=47, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=493, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=47,	'Место'=7
# Пример 14442 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=190, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=112,	'Место'=100
# Пример 14460 является аномалией. При том что: 'Сервис'=61, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=630, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=61,	'Место'=0
# Пример 14468 является аномалией. При том что: 'Сервис'=193, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=45, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=207,	'Место'=285
# Пример 14474 является аномалией. При том что: 'Сервис'=20, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=19, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=20,	'Место'=52
# Пример 14475 является аномалией. При том что: 'Сервис'=158, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=334, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=164,	'Место'=159
# Пример 14480 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=164
# Пример 14482 является аномалией. При том что: 'Сервис'=133, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=5, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=146,	'Место'=65
# Пример 14489 является аномалией. При том что: 'Сервис'=0, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=856, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=0,	'Место'=366
# Пример 14491 является аномалией. При том что: 'Сервис'=133, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=79, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=146,	'Место'=56
# Пример 14493 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=164
# Пример 14496 является аномалией. При том что: 'Сервис'=26, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=616, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=26,	'Место'=169
# Пример 14498 является аномалией. При том что: 'Сервис'=98, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=359, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=99,	'Место'=203
# Пример 14499 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=164
# Пример 14511 является аномалией. При том что: 'Сервис'=107, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=4, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Значительное,	'Система'=110,	'Место'=1
# Пример 14528 является аномалией. При том что: 'Сервис'=66, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=196, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=65,	'Место'=57
# Пример 14552 является аномалией. При том что: 'Сервис'=93, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=377, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Повышенная,	'Влияние'=Нет влияния,	'Система'=92,	'Место'=210
# Пример 14557 является аномалией. При том что: 'Сервис'=65, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=238, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=105,	'Место'=3
# Пример 14565 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=13, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=27
# Пример 14567 является аномалией. При том что: 'Сервис'=25, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=76, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=25,	'Место'=11
# Пример 14575 является аномалией. При том что: 'Сервис'=90, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=705, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=73,	'Место'=1
# Пример 14590 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=14, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=27
# Пример 14598 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=24
# Пример 14621 является аномалией. При том что: 'Сервис'=129, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=37, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=0
# Пример 14649 является аномалией. При том что: 'Сервис'=25, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=76, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=25,	'Место'=9
# Пример 14651 является аномалией. При том что: 'Сервис'=18, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=62, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=18,	'Место'=102
# Пример 14663 является аномалией. При том что: 'Сервис'=2, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=414, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=2,	'Место'=64
# Пример 14669 является аномалией. При том что: 'Сервис'=11, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=42, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Нет       ,	'Влияние'=Малое     ,	'Система'=11,	'Место'=1
# Пример 14677 является аномалией. При том что: 'Сервис'=181, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=25, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=194,	'Место'=20
# Пример 14724 является аномалией. При том что: 'Сервис'=73, 'Приоритет'=Низкий    , 'Статус'=Отменен   , 'Функциональная группа'=472, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Нет       ,	'Влияние'=Нет влияния,	'Система'=71,	'Место'=200
# Пример 14728 является аномалией. При том что: 'Сервис'=23, 'Приоритет'=Средний   , 'Статус'=Закрыт    , 'Функциональная группа'=105, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Особая    ,	'Влияние'=Малое     ,	'Система'=23,	'Место'=1
# Пример 14777 является аномалией. При том что: 'Сервис'=84, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=12, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Базовая   ,	'Влияние'=Нет влияния,	'Система'=312,	'Место'=235
# Пример 14779 является аномалией. При том что: 'Сервис'=93, 'Приоритет'=Низкий    , 'Статус'=Закрыт    , 'Функциональная группа'=234, 'Тип обращения на момент подачи'=Инцидент  , 'Критичность'=Повышенная,	'Влияние'=Малое     ,	'Система'=92,	'Место'=116
# Пример 14791 является аномалией. При том что: 'Сервис'=7, 'Приоритет'=Средний   , 'Статус'=Отменен   , 'Функциональная группа'=18, 'Тип обращения на момент подачи'=Запрос    , 'Критичность'=Особая    ,	'Влияние'=Нет влияния,	'Система'=7,	'Место'=29

# %%
print('Количество аномалий', len(res))
# Out:
# Количество аномалий 1481

# %% [markdown]
# # ВЫВОДЫ
#
# ## Анализ и поиск аномалий с помощью инструмента IsolationForest из пакета библиотеки sklearn.ensemble
#
# ### 1. Закономерности и выявленные Факты
#
# 1.1 — Данны в столбцах "Сервис", "Функциональная группа", "Система" и "Место" не являются ключевыми признаками
#
# 1.2 - Сочетание значений столбцов "Приоритет", "Статус", "Тип обращения на момент подачи", "Критичность" и "Влияние" являются ключивыми признаками при определении Аномалий
#
# ### 2. Описание аномалий
#
# В данном кейсе аномалии можно подразделять на:
#     • Материальные(приводят убытки),
#     • Нематериальные(не приводят или приводят незначительные убытки и без последствий)
#     • Опасные(которые могут привести к аварийным ситуациям и последствиям в будущем)
#
# ### 3. Закономерности при выявлении аномалий, случаи, обноружено разновидностей 7:
# ** Важно, в около 90% случаев аномалии были вызваны не по вине Пользователя.
# Аномалии выявляются в сочетаниях показателей:
#
# 3.1
# Приоритет Низкий — Подача Инцидент — Итог Инцидент — Критичности Нет — Влияние Малое
# В основном это Материальные случаи, замена БП, принтера, и т.д.
#
# 3.2
# Приоритет Низкий — Подача Инцидент — Итог Инцидент — Критичности Нет — Влияние Значительное
#
# Приоритет Низкий — Подача Запрос — Итог Запрос — Критичность Повышенная — Влияние Малое
#
# Приоритет Средний — Подача Инцидент — Итог Инцидент — Критичность Особая — Влияние Малое
#
# В основном это Опасные случаи, отсутствие или ошибки авторизации, при том решения Обходные, имеют накопительный эффект.
#
# 3.3
# Приоритет Средний — Подача Запрос — Итог Запрос — Критичность Особая — Влияния Нет
#
# Приоритет Низкий — Подача Запрос — Итог Запрос — Критичность Нет — Влияния Нет
#
# Приоритет Низкий — Подача Запрос — Итог Запрос — Критичность Особая — Влияния Нет
#
# В основном это Нематериальные случаи, заявки на восстановление пароля, учетной записи и т. д. В основном аномалия из-за неверно указанных значений Критичности Приоритета.
#
# Пути улучшения модели выявления аномалий:
#
# Брать в расчет времянные ряды, особенно в критических Инцидентных случаях когда крайний срок устранения проблемы просрочен.
